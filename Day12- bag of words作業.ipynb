# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %%
corpus[:5]
# Out:
# array(['Wow... Loved this place.', 'Crust is not good.',
#        'Not tasty and the texture was just nasty.',
#        'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.',
#        'The selection on the menu was great and so were the prices.'],
#       dtype=object)

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %%
word_index = {}
index_word = {}
n = 0
for idx,word in enumerate(whole_words):
    word_index[word] = idx
    index_word[idx] = word

# %%
word_index
# Out:
# {'disappoint': 0,
#  'as': 1,
#  'Go': 2,
#  'Just': 3,
#  'cheesecurds': 4,
#  'style': 5,
#  'yummy': 6,
#  'Mellow': 7,
#  'How': 8,
#  'care': 9,
#  'started': 10,
#  'My': 11,
#  'REALLY': 12,
#  'drenched': 13,
#  'selections': 14,
#  'naan': 15,
#  'small': 16,
#  'fill': 17,
#  'moz': 18,
#  'pita': 19,
#  'patty': 20,
#  'why': 21,
#  'inch': 22,
#  'pricing': 23,
#  'poop': 24,
#  'glance': 25,
#  'meat': 26,
#  'theft': 27,
#  'crispy': 28,
#  'tummy': 29,
#  'night': 30,
#  'until': 31,
#  'Both': 32,
#  'falling': 33,
#  'Jamaican': 34,
#  'Hut': 35,
#  'daily': 36,
#  'considering': 37,
#  'Dog': 38,
#  'charge': 39,
#  'Magic': 40,
#  'other': 41,
#  'peas': 42,
#  'maintaining': 43,
#  '5': 44,
#  'evening': 45,
#  'bug': 46,
#  'saffron': 47,
#  'Lordy': 48,
#  'ventilation': 49,
#  'gooodd': 50,
#  'starving': 51,
#  'flavorless': 52,
#  'Good': 53,
#  'APPETIZERS': 54,
#  'crusty': 55,
#  'ache': 56,
#  'many': 57,
#  'across': 58,
#  'black': 59,
#  'attentive': 60,
#  'sexy': 61,
#  'prompt': 62,
#  'about': 63,
#  'Hell': 64,
#  'Yeah': 65,
#  'Fantastic': 66,
#  'Im': 67,
#  'That': 68,
#  'exceptional': 69,
#  'exactly': 70,
#  'extraordinary': 71,
#  'witnessed': 72,
#  'pats': 73,
#  'accident': 74,
#  'sliced': 75,
#  'for': 76,
#  'how': 77,
#  'unsatisfying': 78,
#  'madhouse': 79,
#  'Bad': 80,
#  'min': 81,
#  'profound': 82,
#  'people': 83,
#  'walls': 84,
#  'pay': 85,
#  'gyros': 86,
#  'gave': 87,
#  'pasta': 88,
#  'doing': 89,
#  'like': 90,
#  'bowl': 91,
#  'terrible': 92,
#  'bar': 93,
#  'meh': 94,
#  'stepped': 95,
#  'skimp': 96,
#  'app': 97,
#  'warm': 98,
#  'airline': 99,
#  'heat': 100,
#  'nice': 101,
#  'tomato': 102,
#  'Rick': 103,
#  'too': 104,
#  'whether': 105,
#  'greedy': 106,
#  'fan': 107,
#  'vinegrette': 108,
#  'proven': 109,
#  'rancheros': 110,
#  'winner': 111,
#  'Subway': 112,
#  'he': 113,
#  'He': 114,
#  'ingredients': 115,
#  'yellow': 116,
#  'impeccable': 117,
#  'quite': 118,
#  'glass': 119,
#  'Kids': 120,
#  'Maria': 121,
#  'Must': 122,
#  'condiment': 123,
#  'awkwardly': 124,
#  '1/2': 125,
#  'reviews': 126,
#  'eel': 127,
#  'most': 128,
#  'seasoning': 129,
#  'go': 130,
#  'AVOID': 131,
#  'seasoned': 132,
#  'without': 133,
#  'texture': 134,
#  'always': 135,
#  'pile': 136,
#  'blue': 137,
#  'maybe': 138,
#  'owner/chef': 139,
#  'onion': 140,
#  'mouthful': 141,
#  'MANY': 142,
#  'tough': 143,
#  'third': 144,
#  'May': 145,
#  'tongue': 146,
#  'mouth': 147,
#  'dough': 148,
#  'bus': 149,
#  'mile': 150,
#  'friendly': 151,
#  'containers': 152,
#  'slow': 153,
#  'Update': 154,
#  'Steak': 155,
#  'tea': 156,
#  'oil': 157,
#  'salads': 158,
#  'industry': 159,
#  'coconut': 160,
#  'of': 161,
#  'papers': 162,
#  'dressing': 163,
#  'guys': 164,
#  'we': 165,
#  'Worse': 166,
#  'plethora': 167,
#  'crowd': 168,
#  'Their': 169,
#  'has': 170,
#  'Caesar': 171,
#  'bread': 172,
#  'drawing': 173,
#  'under': 174,
#  'serve': 175,
#  'less': 176,
#  'waste': 177,
#  'opinion': 178,
#  'Ninja': 179,
#  'Spend': 180,
#  'Left': 181,
#  'expect': 182,
#  'revisiting': 183,
#  'Please': 184,
#  'BBQ': 185,
#  "'s": 186,
#  'TIME': 187,
#  'potato': 188,
#  'return': 189,
#  'gas': 190,
#  'MANAGEMENT': 191,
#  'Mary': 192,
#  'picture': 193,
#  'BEST': 194,
#  'thats': 195,
#  'someone': 196,
#  'caring': 197,
#  'become': 198,
#  'inviting': 199,
#  'LEGIT': 200,
#  'outrageously': 201,
#  'douchey': 202,
#  'read': 203,
#  'enjoyable': 204,
#  'incredibly': 205,
#  'price': 206,
#  'atmosphere': 207,
#  'its': 208,
#  'prepare': 209,
#  'rate': 210,
#  'bad': 211,
#  'tolerance': 212,
#  'changing': 213,
#  'what': 214,
#  'venture': 215,
#  '&': 216,
#  'properly': 217,
#  'sergeant': 218,
#  'Now': 219,
#  'nigiri': 220,
#  'muffin': 221,
#  'eyed': 222,
#  'mediocre': 223,
#  'toasted': 224,
#  'mesquite': 225,
#  'providing': 226,
#  'spends': 227,
#  'donut': 228,
#  'bamboo': 229,
#  'mistake': 230,
#  'Terrible': 231,
#  'IT': 232,
#  'boys': 233,
#  'tried': 234,
#  'quality': 235,
#  'drive': 236,
#  'honor': 237,
#  'disbelief': 238,
#  'meatballs': 239,
#  'nicest': 240,
#  'quit': 241,
#  'olives': 242,
#  'Ambience': 243,
#  ':': 244,
#  'vacant': 245,
#  'bakery': 246,
#  'Gyros': 247,
#  'efficient': 248,
#  'self': 249,
#  'Big': 250,
#  'portions': 251,
#  'single': 252,
#  'greens': 253,
#  'Strip': 254,
#  'bellies': 255,
#  'memory': 256,
#  'latte': 257,
#  'cut': 258,
#  'pizza': 259,
#  'looking': 260,
#  'juice..': 261,
#  'non-customer': 262,
#  'hurry': 263,
#  'to-go': 264,
#  'Bacon': 265,
#  'LOVED': 266,
#  'sense': 267,
#  'generic': 268,
#  'sign': 269,
#  'personable': 270,
#  'incredible': 271,
#  'Sat': 272,
#  '4': 273,
#  'OF': 274,
#  'bit': 275,
#  'beans': 276,
#  'this': 277,
#  'Blah': 278,
#  'Favorite': 279,
#  'burger': 280,
#  'into': 281,
#  'poor': 282,
#  'while': 283,
#  '``': 284,
#  'complain': 285,
#  'climbing': 286,
#  'slices': 287,
#  'cooking': 288,
#  'RUDE': 289,
#  'employee': 290,
#  'Baba': 291,
#  'Eew': 292,
#  'definitely': 293,
#  '.the': 294,
#  'limited': 295,
#  'drastically': 296,
#  'besides': 297,
#  'Frenchman': 298,
#  'wildly': 299,
#  'sharply': 300,
#  'HAPPENED': 301,
#  'HAD': 302,
#  'Why': 303,
#  'Def': 304,
#  "'re": 305,
#  'Japanese': 306,
#  'Would': 307,
#  'book': 308,
#  'arriving': 309,
#  'Mushroom': 310,
#  'eat': 311,
#  'not': 312,
#  'located': 313,
#  'average': 314,
#  'Thus': 315,
#  'find': 316,
#  'HAVE': 317,
#  'satifying': 318,
#  'silently': 319,
#  'fries': 320,
#  'want': 321,
#  'Cooked': 322,
#  'Khao': 323,
#  'seating': 324,
#  'After': 325,
#  'fireball': 326,
#  'inside': 327,
#  'boba': 328,
#  'chicken': 329,
#  'ate': 330,
#  'pears': 331,
#  '10+': 332,
#  '70+': 333,
#  "'ve": 334,
#  'town': 335,
#  'poured': 336,
#  'flavor': 337,
#  'military': 338,
#  'rather': 339,
#  'guy': 340,
#  'rest': 341,
#  'choose': 342,
#  'Voodoo': 343,
#  'hardly': 344,
#  'seafood': 345,
#  'scallop': 346,
#  'bruschetta': 347,
#  'Palm': 348,
#  'actual': 349,
#  'Bellagio': 350,
#  'AZ': 351,
#  'WEAK': 352,
#  'Similarly': 353,
#  'humiliated': 354,
#  'recall': 355,
#  'several': 356,
#  '30': 357,
#  '-Drinks': 358,
#  'high': 359,
#  'experience': 360,
#  'blow': 361,
#  'party': 362,
#  'Mediocre': 363,
#  'Perfect': 364,
#  'prime': 365,
#  'typical': 366,
#  '...': 367,
#  'ask': 368,
#  'companions': 369,
#  'degree': 370,
#  'solidify': 371,
#  'spaghetti': 372,
#  'somehow': 373,
#  'Join': 374,
#  'caterpillar': 375,
#  'freaking': 376,
#  'whole': 377,
#  'Soups': 378,
#  'that': 379,
#  'Do': 380,
#  'accordingly': 381,
#  'or': 382,
#  'insulted': 383,
#  'dropped': 384,
#  'BARGAIN': 385,
#  'still': 386,
#  'Baseball': 387,
#  'lots': 388,
#  'tables': 389,
#  'gluten': 390,
#  'refused': 391,
#  'shrimp': 392,
#  'double': 393,
#  'martini': 394,
#  'hour': 395,
#  'milk': 396,
#  'awkward': 397,
#  'Four': 398,
#  'happier': 399,
#  'course': 400,
#  'fav': 401,
#  'Ironman': 402,
#  'smaller': 403,
#  'chai': 404,
#  'speedy': 405,
#  'only': 406,
#  'bottom': 407,
#  'sewer': 408,
#  '1': 409,
#  'indicate': 410,
#  'went': 411,
#  'even': 412,
#  'front': 413,
#  'spring': 414,
#  'provides': 415,
#  'held': 416,
#  'cute': 417,
#  'you': 418,
#  'deserves': 419,
#  'remember': 420,
#  'wife': 421,
#  'covers': 422,
#  'dead': 423,
#  'Weird': 424,
#  'wait': 425,
#  'pancakes': 426,
#  'round': 427,
#  'rubber': 428,
#  'sause': 429,
#  'actually': 430,
#  'Steiners': 431,
#  'yet': 432,
#  'show': 433,
#  'Delight': 434,
#  'hearts': 435,
#  'thirty': 436,
#  'unfortunately': 437,
#  'supposed': 438,
#  'light': 439,
#  'char': 440,
#  'GO': 441,
#  'Your': 442,
#  'Dylan': 443,
#  'Everything': 444,
#  'beauty': 445,
#  'favorite': 446,
#  'fun': 447,
#  'neither': 448,
#  'attention': 449,
#  'almonds': 450,
#  'delicious': 451,
#  'Awesome': 452,
#  'room': 453,
#  'usual': 454,
#  'killer': 455,
#  'familiar': 456,
#  'shoe': 457,
#  'watch': 458,
#  'decorated': 459,
#  'liked': 460,
#  'if': 461,
#  'Back': 462,
#  'Francisco': 463,
#  'concept': 464,
#  'lot': 465,
#  'fella': 466,
#  'years': 467,
#  'quickly': 468,
#  'Of': 469,
#  'bodes': 470,
#  'fairly': 471,
#  'hi': 472,
#  'extensive': 473,
#  'twice': 474,
#  'appalling': 475,
#  'smooth': 476,
#  'hard': 477,
#  'from': 478,
#  'lovers': 479,
#  'gets': 480,
#  'occasions': 481,
#  'highlighted': 482,
#  'foods': 483,
#  'craving': 484,
#  'baby': 485,
#  'dipping': 486,
#  'fine': 487,
#  'In': 488,
#  'mojitos': 489,
#  'tartare': 490,
#  'overpriced': 491,
#  'returning': 492,
#  'expert/connisseur': 493,
#  'hereas': 494,
#  'common': 495,
#  'off': 496,
#  'hit': 497,
#  'Great': 498,
#  'Nobu': 499,
#  'dine': 500,
#  'space': 501,
#  'breaks': 502,
#  'genuinely': 503,
#  'totally': 504,
#  'portion': 505,
#  'getting': 506,
#  'requested': 507,
#  'pepper': 508,
#  'Furthermore': 509,
#  'got': 510,
#  'NOW': 511,
#  'biscuit': 512,
#  'FANTASTIC': 513,
#  'us': 514,
#  'reminded': 515,
#  'carbs': 516,
#  'happened': 517,
#  'showed': 518,
#  '*heart*': 519,
#  'STALE': 520,
#  'stuff': 521,
#  'flirting': 522,
#  'opposed': 523,
#  'asking': 524,
#  'servers': 525,
#  'send': 526,
#  'came': 527,
#  'Nargile': 528,
#  'A': 529,
#  'exceeding': 530,
#  'Gordon': 531,
#  'it': 532,
#  'choux': 533,
#  'to': 534,
#  'due': 535,
#  'par': 536,
#  'hottest': 537,
#  'die': 538,
#  'fiancé': 539,
#  'anyone': 540,
#  'bartenders': 541,
#  'Edinburgh': 542,
#  'watered': 543,
#  'decent': 544,
#  'hope': 545,
#  'Ians': 546,
#  'Pricing': 547,
#  'ball': 548,
#  'serivce': 549,
#  'sit-down': 550,
#  'callings': 551,
#  'felt': 552,
#  'It': 553,
#  'leather': 554,
#  'hardest': 555,
#  'must-stop': 556,
#  'my': 557,
#  'helped': 558,
#  'bone': 559,
#  'unless': 560,
#  'imagined': 561,
#  'soooooo': 562,
#  'boxes': 563,
#  'play': 564,
#  'bloodiest': 565,
#  'Mmmm': 566,
#  'Lemon': 567,
#  'beat': 568,
#  'day': 569,
#  'waiter': 570,
#  'haunt': 571,
#  'roasted': 572,
#  'WILL': 573,
#  'turkey': 574,
#  'alone': 575,
#  'modern': 576,
#  'deeply': 577,
#  'away': 578,
#  'Ample': 579,
#  'interior': 580,
#  'Heart': 581,
#  'relocated': 582,
#  'included': 583,
#  'etc': 584,
#  'leftover': 585,
#  'spicier': 586,
#  'an': 587,
#  'WHAT': 588,
#  'Horrible': 589,
#  'ladies': 590,
#  'Jeff': 591,
#  'letting': 592,
#  'sushi': 593,
#  'Phenomenal': 594,
#  'each': 595,
#  'enjoyed': 596,
#  'Needless': 597,
#  'hungry': 598,
#  'disgraceful': 599,
#  'menus': 600,
#  'more': 601,
#  'chewy': 602,
#  'year': 603,
#  'PEOPLE': 604,
#  'Elk': 605,
#  'never': 606,
#  'empty': 607,
#  'tots': 608,
#  'salsa': 609,
#  'easily': 610,
#  'STEP': 611,
#  'Cibo': 612,
#  'anticipated': 613,
#  'Before': 614,
#  'fat': 615,
#  'lacked': 616,
#  'Overall': 617,
#  'gratitude': 618,
#  'moist': 619,
#  'concern': 620,
#  'Avoid': 621,
#  'seasonal': 622,
#  'make': 623,
#  'all': 624,
#  'ever': 625,
#  'bye': 626,
#  'at': 627,
#  'every': 628,
#  'feeling': 629,
#  'rib': 630,
#  'Panna': 631,
#  'patron': 632,
#  'mom': 633,
#  'frozen': 634,
#  'serves': 635,
#  'packed': 636,
#  'Took': 637,
#  'Mango': 638,
#  '/hand': 639,
#  'also': 640,
#  'salt': 641,
#  'Thoroughly': 642,
#  'pan': 643,
#  'Disappointing': 644,
#  'Flower': 645,
#  'proclaimed': 646,
#  'website': 647,
#  'seated': 648,
#  'world': 649,
#  'Delicious': 650,
#  'drunk': 651,
#  'rge': 652,
#  'gratuity': 653,
#  'inexpensive': 654,
#  'REAL': 655,
#  'gotten': 656,
#  'Costco': 657,
#  'They': 658,
#  'High-quality': 659,
#  'same': 660,
#  'beautiful': 661,
#  'THIS': 662,
#  'miss': 663,
#  'monster': 664,
#  'grandmother': 665,
#  'thick': 666,
#  'cranberry': 667,
#  'menu/': 668,
#  'Dos': 669,
#  'anything': 670,
#  'Lastly': 671,
#  'Salad': 672,
#  'lovely': 673,
#  'menu': 674,
#  'might': 675,
#  'mmmm': 676,
#  'wound': 677,
#  'satisfied': 678,
#  'melt': 679,
#  'pretty': 680,
#  'Hiro': 681,
#  'attack': 682,
#  'scene': 683,
#  'dressed': 684,
#  'disgust': 685,
#  'Main': 686,
#  'godfathers': 687,
#  'HANDS': 688,
#  '%': 689,
#  'part': 690,
#  'meal': 691,
#  'cocktails': 692,
#  'melted': 693,
#  'breakfast': 694,
#  'potatoes': 695,
#  'made': 696,
#  'bits': 697,
#  'duo': 698,
#  'HOUR': 699,
#  'completely': 700,
#  'short': 701,
#  'consider': 702,
#  'two': 703,
#  'parties': 704,
#  'best': 705,
#  'loves': 706,
#  'Toast': 707,
#  'absolutley': 708,
#  'some': 709,
#  'cashew': 710,
#  'solid': 711,
#  'cake': 712,
#  'use': 713,
#  'email': 714,
#  '3': 715,
#  'known': 716,
#  'dirty-': 717,
#  'So': 718,
#  'roast': 719,
#  'again': 720,
#  'Excalibur': 721,
#  'certainly': 722,
#  'crawfish': 723,
#  'bacon': 724,
#  'yellowtail': 725,
#  'healthy': 726,
#  'provided': 727,
#  'perfect': 728,
#  'diverse': 729,
#  'bagels': 730,
#  'words': 731,
#  'EXPERIENCE': 732,
#  'here': 733,
#  'brought': 734,
#  'guests': 735,
#  'BARE': 736,
#  'taco': 737,
#  'longer': 738,
#  'atmosphere.1': 739,
#  'Bisque': 740,
#  'Maine': 741,
#  'regularly': 742,
#  'truly': 743,
#  'Pineapple': 744,
#  'claimed': 745,
#  'waiting': 746,
#  'dog': 747,
#  'dishes': 748,
#  'person': 749,
#  'week': 750,
#  'bland': 751,
#  'mean': 752,
#  'Hunan': 753,
#  'Overpriced': 754,
#  'disgusting': 755,
#  'publicly': 756,
#  'Only': 757,
#  'Tried': 758,
#  'readers': 759,
#  'everyone': 760,
#  'middle': 761,
#  'absolute': 762,
#  'English': 763,
#  'thanks': 764,
#  'none': 765,
#  'Salads': 766,
#  'eyes': 767,
#  'so': 768,
#  'presentation': 769,
#  'touch': 770,
#  'Mediterranean': 771,
#  'ribeye': 772,
#  'past': 773,
#  'Bachi': 774,
#  'nude': 775,
#  'TOTAL': 776,
#  'Are': 777,
#  'circumstances': 778,
#  'temp.I': 779,
#  'delight': 780,
#  'Burrittos': 781,
#  'puree': 782,
#  'These': 783,
#  'perfection': 784,
#  'Chicken': 785,
#  'below': 786,
#  'realized': 787,
#  'huevos': 788,
#  'pop': 789,
#  'owner': 790,
#  'up': 791,
#  'unbelievable': 792,
#  'seems': 793,
#  'courteous': 794,
#  'received': 795,
#  'Place': 796,
#  'Special': 797,
#  'company': 798,
#  'saying': 799,
#  'NEVER': 800,
#  'outside': 801,
#  'waited': 802,
#  'mains': 803,
#  'mouths': 804,
#  'Come': 805,
#  'lacking': 806,
#  'juries': 807,
#  'number': 808,
#  'accountant': 809,
#  'literally': 810,
#  'hated': 811,
#  'decide': 812,
#  'capers': 813,
#  'bloddy': 814,
#  'fish': 815,
#  'North': 816,
#  'pulled': 817,
#  'tip': 818,
#  'behind': 819,
#  'doubt': 820,
#  'rowdy': 821,
#  'almost': 822,
#  'slaw': 823,
#  'much': 824,
#  'curry': 825,
#  'pho': 826,
#  'crepe': 827,
#  'low': 828,
#  'Ha': 829,
#  'instead': 830,
#  'dime': 831,
#  'desserts': 832,
#  'colder': 833,
#  'fruit': 834,
#  'barely': 835,
#  'original': 836,
#  'fucking': 837,
#  'peanuts': 838,
#  'Those': 839,
#  'Sprouts': 840,
#  'acknowledged': 841,
#  'ways': 842,
#  'server': 843,
#  'preparing': 844,
#  'outta': 845,
#  'could': 846,
#  'handling': 847,
#  'fo': 848,
#  'belly': 849,
#  'Egg': 850,
#  'beyond': 851,
#  'delivery': 852,
#  'salmon': 853,
#  'Long': 854,
#  'succulent': 855,
#  'clue': 856,
#  'Boy': 857,
#  '30s': 858,
#  'Talk': 859,
#  'fuzzy': 860,
#  "'ll": 861,
#  'customize': 862,
#  'complete': 863,
#  'nasty': 864,
#  'stay': 865,
#  'used': 866,
#  'had': 867,
#  'fried': 868,
#  'Crema': 869,
#  'rarely': 870,
#  'AYCE': 871,
#  'probably': 872,
#  'Could': 873,
#  'garden': 874,
#  'rice': 875,
#  'lil': 876,
#  'rave': 877,
#  'area/': 878,
#  'oh': 879,
#  'super': 880,
#  'Waiter': 881,
#  'thin': 882,
#  'means': 883,
#  'shocked': 884,
#  'From': 885,
#  'ordering': 886,
#  'The': 887,
#  'ourselves': 888,
#  'mess': 889,
#  'they': 890,
#  'hospitality': 891,
#  'mussels': 892,
#  '2007': 893,
#  'recommending': 894,
#  'take': 895,
#  'sucker': 896,
#  'deal': 897,
#  'egg': 898,
#  'pucks': 899,
#  'section': 900,
#  'Noca': 901,
#  'manager': 902,
#  'mac': 903,
#  'Plus': 904,
#  'duck': 905,
#  'bars': 906,
#  'sub-par': 907,
#  'pub': 908,
#  'talk': 909,
#  "ya'all": 910,
#  'elsewhere': 911,
#  'working/eating': 912,
#  'steaks': 913,
#  'suffers': 914,
#  'being': 915,
#  'itself': 916,
#  'grossed': 917,
#  'foot': 918,
#  'Crostini': 919,
#  'ambience': 920,
#  'Sushi': 921,
#  'grill': 922,
#  'pastas': 923,
#  'operation': 924,
#  'wings': 925,
#  'asked': 926,
#  'And': 927,
#  'summer': 928,
#  'consistent': 929,
#  'mood': 930,
#  'despicable': 931,
#  'crisp': 932,
#  'hamburger': 933,
#  'wontons': 934,
#  '$': 935,
#  'downright': 936,
#  'Hot': 937,
#  'tacos': 938,
#  'sals': 939,
#  'Highly': 940,
#  'kid': 941,
#  'impressive': 942,
#  'allergy': 943,
#  'trips': 944,
#  'extremely': 945,
#  'amount': 946,
#  '.THE': 947,
#  'Soggy': 948,
#  'petrified': 949,
#  'Eve': 950,
#  'Mexican': 951,
#  'favor': 952,
#  '12': 953,
#  'Nan': 954,
#  'serving': 955,
#  'tasted': 956,
#  'vegetarian': 957,
#  'towards': 958,
#  'informative': 959,
#  'tasteless': 960,
#  'Mom': 961,
#  'sashimi': 962,
#  'surprised': 963,
#  'final': 964,
#  'name': 965,
#  'Risotto': 966,
#  'live': 967,
#  'Heimer': 968,
#  'cannoli': 969,
#  'Last': 970,
#  'green': 971,
#  'awful': 972,
#  'mind': 973,
#  'folks': 974,
#  'binge': 975,
#  'hello': 976,
#  'Have': 977,
#  'Host': 978,
#  'restaraunt': 979,
#  'weekend': 980,
#  'flat': 981,
#  'human': 982,
#  'WAAAAAAyyyyyyyyyy': 983,
#  'be': 984,
#  'better': 985,
#  'recommend': 986,
#  'kiddos': 987,
#  '.way': 988,
#  'surprise': 989,
#  'highly': 990,
#  '2': 991,
#  'customer': 992,
#  'hoping': 993,
#  'visit': 994,
#  'piano': 995,
#  'seen': 996,
#  'stop': 997,
#  'sat': 998,
#  'mention': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'disappoint',
#  1: 'as',
#  2: 'Go',
#  3: 'Just',
#  4: 'cheesecurds',
#  5: 'style',
#  6: 'yummy',
#  7: 'Mellow',
#  8: 'How',
#  9: 'care',
#  10: 'started',
#  11: 'My',
#  12: 'REALLY',
#  13: 'drenched',
#  14: 'selections',
#  15: 'naan',
#  16: 'small',
#  17: 'fill',
#  18: 'moz',
#  19: 'pita',
#  20: 'patty',
#  21: 'why',
#  22: 'inch',
#  23: 'pricing',
#  24: 'poop',
#  25: 'glance',
#  26: 'meat',
#  27: 'theft',
#  28: 'crispy',
#  29: 'tummy',
#  30: 'night',
#  31: 'until',
#  32: 'Both',
#  33: 'falling',
#  34: 'Jamaican',
#  35: 'Hut',
#  36: 'daily',
#  37: 'considering',
#  38: 'Dog',
#  39: 'charge',
#  40: 'Magic',
#  41: 'other',
#  42: 'peas',
#  43: 'maintaining',
#  44: '5',
#  45: 'evening',
#  46: 'bug',
#  47: 'saffron',
#  48: 'Lordy',
#  49: 'ventilation',
#  50: 'gooodd',
#  51: 'starving',
#  52: 'flavorless',
#  53: 'Good',
#  54: 'APPETIZERS',
#  55: 'crusty',
#  56: 'ache',
#  57: 'many',
#  58: 'across',
#  59: 'black',
#  60: 'attentive',
#  61: 'sexy',
#  62: 'prompt',
#  63: 'about',
#  64: 'Hell',
#  65: 'Yeah',
#  66: 'Fantastic',
#  67: 'Im',
#  68: 'That',
#  69: 'exceptional',
#  70: 'exactly',
#  71: 'extraordinary',
#  72: 'witnessed',
#  73: 'pats',
#  74: 'accident',
#  75: 'sliced',
#  76: 'for',
#  77: 'how',
#  78: 'unsatisfying',
#  79: 'madhouse',
#  80: 'Bad',
#  81: 'min',
#  82: 'profound',
#  83: 'people',
#  84: 'walls',
#  85: 'pay',
#  86: 'gyros',
#  87: 'gave',
#  88: 'pasta',
#  89: 'doing',
#  90: 'like',
#  91: 'bowl',
#  92: 'terrible',
#  93: 'bar',
#  94: 'meh',
#  95: 'stepped',
#  96: 'skimp',
#  97: 'app',
#  98: 'warm',
#  99: 'airline',
#  100: 'heat',
#  101: 'nice',
#  102: 'tomato',
#  103: 'Rick',
#  104: 'too',
#  105: 'whether',
#  106: 'greedy',
#  107: 'fan',
#  108: 'vinegrette',
#  109: 'proven',
#  110: 'rancheros',
#  111: 'winner',
#  112: 'Subway',
#  113: 'he',
#  114: 'He',
#  115: 'ingredients',
#  116: 'yellow',
#  117: 'impeccable',
#  118: 'quite',
#  119: 'glass',
#  120: 'Kids',
#  121: 'Maria',
#  122: 'Must',
#  123: 'condiment',
#  124: 'awkwardly',
#  125: '1/2',
#  126: 'reviews',
#  127: 'eel',
#  128: 'most',
#  129: 'seasoning',
#  130: 'go',
#  131: 'AVOID',
#  132: 'seasoned',
#  133: 'without',
#  134: 'texture',
#  135: 'always',
#  136: 'pile',
#  137: 'blue',
#  138: 'maybe',
#  139: 'owner/chef',
#  140: 'onion',
#  141: 'mouthful',
#  142: 'MANY',
#  143: 'tough',
#  144: 'third',
#  145: 'May',
#  146: 'tongue',
#  147: 'mouth',
#  148: 'dough',
#  149: 'bus',
#  150: 'mile',
#  151: 'friendly',
#  152: 'containers',
#  153: 'slow',
#  154: 'Update',
#  155: 'Steak',
#  156: 'tea',
#  157: 'oil',
#  158: 'salads',
#  159: 'industry',
#  160: 'coconut',
#  161: 'of',
#  162: 'papers',
#  163: 'dressing',
#  164: 'guys',
#  165: 'we',
#  166: 'Worse',
#  167: 'plethora',
#  168: 'crowd',
#  169: 'Their',
#  170: 'has',
#  171: 'Caesar',
#  172: 'bread',
#  173: 'drawing',
#  174: 'under',
#  175: 'serve',
#  176: 'less',
#  177: 'waste',
#  178: 'opinion',
#  179: 'Ninja',
#  180: 'Spend',
#  181: 'Left',
#  182: 'expect',
#  183: 'revisiting',
#  184: 'Please',
#  185: 'BBQ',
#  186: "'s",
#  187: 'TIME',
#  188: 'potato',
#  189: 'return',
#  190: 'gas',
#  191: 'MANAGEMENT',
#  192: 'Mary',
#  193: 'picture',
#  194: 'BEST',
#  195: 'thats',
#  196: 'someone',
#  197: 'caring',
#  198: 'become',
#  199: 'inviting',
#  200: 'LEGIT',
#  201: 'outrageously',
#  202: 'douchey',
#  203: 'read',
#  204: 'enjoyable',
#  205: 'incredibly',
#  206: 'price',
#  207: 'atmosphere',
#  208: 'its',
#  209: 'prepare',
#  210: 'rate',
#  211: 'bad',
#  212: 'tolerance',
#  213: 'changing',
#  214: 'what',
#  215: 'venture',
#  216: '&',
#  217: 'properly',
#  218: 'sergeant',
#  219: 'Now',
#  220: 'nigiri',
#  221: 'muffin',
#  222: 'eyed',
#  223: 'mediocre',
#  224: 'toasted',
#  225: 'mesquite',
#  226: 'providing',
#  227: 'spends',
#  228: 'donut',
#  229: 'bamboo',
#  230: 'mistake',
#  231: 'Terrible',
#  232: 'IT',
#  233: 'boys',
#  234: 'tried',
#  235: 'quality',
#  236: 'drive',
#  237: 'honor',
#  238: 'disbelief',
#  239: 'meatballs',
#  240: 'nicest',
#  241: 'quit',
#  242: 'olives',
#  243: 'Ambience',
#  244: ':',
#  245: 'vacant',
#  246: 'bakery',
#  247: 'Gyros',
#  248: 'efficient',
#  249: 'self',
#  250: 'Big',
#  251: 'portions',
#  252: 'single',
#  253: 'greens',
#  254: 'Strip',
#  255: 'bellies',
#  256: 'memory',
#  257: 'latte',
#  258: 'cut',
#  259: 'pizza',
#  260: 'looking',
#  261: 'juice..',
#  262: 'non-customer',
#  263: 'hurry',
#  264: 'to-go',
#  265: 'Bacon',
#  266: 'LOVED',
#  267: 'sense',
#  268: 'generic',
#  269: 'sign',
#  270: 'personable',
#  271: 'incredible',
#  272: 'Sat',
#  273: '4',
#  274: 'OF',
#  275: 'bit',
#  276: 'beans',
#  277: 'this',
#  278: 'Blah',
#  279: 'Favorite',
#  280: 'burger',
#  281: 'into',
#  282: 'poor',
#  283: 'while',
#  284: '``',
#  285: 'complain',
#  286: 'climbing',
#  287: 'slices',
#  288: 'cooking',
#  289: 'RUDE',
#  290: 'employee',
#  291: 'Baba',
#  292: 'Eew',
#  293: 'definitely',
#  294: '.the',
#  295: 'limited',
#  296: 'drastically',
#  297: 'besides',
#  298: 'Frenchman',
#  299: 'wildly',
#  300: 'sharply',
#  301: 'HAPPENED',
#  302: 'HAD',
#  303: 'Why',
#  304: 'Def',
#  305: "'re",
#  306: 'Japanese',
#  307: 'Would',
#  308: 'book',
#  309: 'arriving',
#  310: 'Mushroom',
#  311: 'eat',
#  312: 'not',
#  313: 'located',
#  314: 'average',
#  315: 'Thus',
#  316: 'find',
#  317: 'HAVE',
#  318: 'satifying',
#  319: 'silently',
#  320: 'fries',
#  321: 'want',
#  322: 'Cooked',
#  323: 'Khao',
#  324: 'seating',
#  325: 'After',
#  326: 'fireball',
#  327: 'inside',
#  328: 'boba',
#  329: 'chicken',
#  330: 'ate',
#  331: 'pears',
#  332: '10+',
#  333: '70+',
#  334: "'ve",
#  335: 'town',
#  336: 'poured',
#  337: 'flavor',
#  338: 'military',
#  339: 'rather',
#  340: 'guy',
#  341: 'rest',
#  342: 'choose',
#  343: 'Voodoo',
#  344: 'hardly',
#  345: 'seafood',
#  346: 'scallop',
#  347: 'bruschetta',
#  348: 'Palm',
#  349: 'actual',
#  350: 'Bellagio',
#  351: 'AZ',
#  352: 'WEAK',
#  353: 'Similarly',
#  354: 'humiliated',
#  355: 'recall',
#  356: 'several',
#  357: '30',
#  358: '-Drinks',
#  359: 'high',
#  360: 'experience',
#  361: 'blow',
#  362: 'party',
#  363: 'Mediocre',
#  364: 'Perfect',
#  365: 'prime',
#  366: 'typical',
#  367: '...',
#  368: 'ask',
#  369: 'companions',
#  370: 'degree',
#  371: 'solidify',
#  372: 'spaghetti',
#  373: 'somehow',
#  374: 'Join',
#  375: 'caterpillar',
#  376: 'freaking',
#  377: 'whole',
#  378: 'Soups',
#  379: 'that',
#  380: 'Do',
#  381: 'accordingly',
#  382: 'or',
#  383: 'insulted',
#  384: 'dropped',
#  385: 'BARGAIN',
#  386: 'still',
#  387: 'Baseball',
#  388: 'lots',
#  389: 'tables',
#  390: 'gluten',
#  391: 'refused',
#  392: 'shrimp',
#  393: 'double',
#  394: 'martini',
#  395: 'hour',
#  396: 'milk',
#  397: 'awkward',
#  398: 'Four',
#  399: 'happier',
#  400: 'course',
#  401: 'fav',
#  402: 'Ironman',
#  403: 'smaller',
#  404: 'chai',
#  405: 'speedy',
#  406: 'only',
#  407: 'bottom',
#  408: 'sewer',
#  409: '1',
#  410: 'indicate',
#  411: 'went',
#  412: 'even',
#  413: 'front',
#  414: 'spring',
#  415: 'provides',
#  416: 'held',
#  417: 'cute',
#  418: 'you',
#  419: 'deserves',
#  420: 'remember',
#  421: 'wife',
#  422: 'covers',
#  423: 'dead',
#  424: 'Weird',
#  425: 'wait',
#  426: 'pancakes',
#  427: 'round',
#  428: 'rubber',
#  429: 'sause',
#  430: 'actually',
#  431: 'Steiners',
#  432: 'yet',
#  433: 'show',
#  434: 'Delight',
#  435: 'hearts',
#  436: 'thirty',
#  437: 'unfortunately',
#  438: 'supposed',
#  439: 'light',
#  440: 'char',
#  441: 'GO',
#  442: 'Your',
#  443: 'Dylan',
#  444: 'Everything',
#  445: 'beauty',
#  446: 'favorite',
#  447: 'fun',
#  448: 'neither',
#  449: 'attention',
#  450: 'almonds',
#  451: 'delicious',
#  452: 'Awesome',
#  453: 'room',
#  454: 'usual',
#  455: 'killer',
#  456: 'familiar',
#  457: 'shoe',
#  458: 'watch',
#  459: 'decorated',
#  460: 'liked',
#  461: 'if',
#  462: 'Back',
#  463: 'Francisco',
#  464: 'concept',
#  465: 'lot',
#  466: 'fella',
#  467: 'years',
#  468: 'quickly',
#  469: 'Of',
#  470: 'bodes',
#  471: 'fairly',
#  472: 'hi',
#  473: 'extensive',
#  474: 'twice',
#  475: 'appalling',
#  476: 'smooth',
#  477: 'hard',
#  478: 'from',
#  479: 'lovers',
#  480: 'gets',
#  481: 'occasions',
#  482: 'highlighted',
#  483: 'foods',
#  484: 'craving',
#  485: 'baby',
#  486: 'dipping',
#  487: 'fine',
#  488: 'In',
#  489: 'mojitos',
#  490: 'tartare',
#  491: 'overpriced',
#  492: 'returning',
#  493: 'expert/connisseur',
#  494: 'hereas',
#  495: 'common',
#  496: 'off',
#  497: 'hit',
#  498: 'Great',
#  499: 'Nobu',
#  500: 'dine',
#  501: 'space',
#  502: 'breaks',
#  503: 'genuinely',
#  504: 'totally',
#  505: 'portion',
#  506: 'getting',
#  507: 'requested',
#  508: 'pepper',
#  509: 'Furthermore',
#  510: 'got',
#  511: 'NOW',
#  512: 'biscuit',
#  513: 'FANTASTIC',
#  514: 'us',
#  515: 'reminded',
#  516: 'carbs',
#  517: 'happened',
#  518: 'showed',
#  519: '*heart*',
#  520: 'STALE',
#  521: 'stuff',
#  522: 'flirting',
#  523: 'opposed',
#  524: 'asking',
#  525: 'servers',
#  526: 'send',
#  527: 'came',
#  528: 'Nargile',
#  529: 'A',
#  530: 'exceeding',
#  531: 'Gordon',
#  532: 'it',
#  533: 'choux',
#  534: 'to',
#  535: 'due',
#  536: 'par',
#  537: 'hottest',
#  538: 'die',
#  539: 'fiancé',
#  540: 'anyone',
#  541: 'bartenders',
#  542: 'Edinburgh',
#  543: 'watered',
#  544: 'decent',
#  545: 'hope',
#  546: 'Ians',
#  547: 'Pricing',
#  548: 'ball',
#  549: 'serivce',
#  550: 'sit-down',
#  551: 'callings',
#  552: 'felt',
#  553: 'It',
#  554: 'leather',
#  555: 'hardest',
#  556: 'must-stop',
#  557: 'my',
#  558: 'helped',
#  559: 'bone',
#  560: 'unless',
#  561: 'imagined',
#  562: 'soooooo',
#  563: 'boxes',
#  564: 'play',
#  565: 'bloodiest',
#  566: 'Mmmm',
#  567: 'Lemon',
#  568: 'beat',
#  569: 'day',
#  570: 'waiter',
#  571: 'haunt',
#  572: 'roasted',
#  573: 'WILL',
#  574: 'turkey',
#  575: 'alone',
#  576: 'modern',
#  577: 'deeply',
#  578: 'away',
#  579: 'Ample',
#  580: 'interior',
#  581: 'Heart',
#  582: 'relocated',
#  583: 'included',
#  584: 'etc',
#  585: 'leftover',
#  586: 'spicier',
#  587: 'an',
#  588: 'WHAT',
#  589: 'Horrible',
#  590: 'ladies',
#  591: 'Jeff',
#  592: 'letting',
#  593: 'sushi',
#  594: 'Phenomenal',
#  595: 'each',
#  596: 'enjoyed',
#  597: 'Needless',
#  598: 'hungry',
#  599: 'disgraceful',
#  600: 'menus',
#  601: 'more',
#  602: 'chewy',
#  603: 'year',
#  604: 'PEOPLE',
#  605: 'Elk',
#  606: 'never',
#  607: 'empty',
#  608: 'tots',
#  609: 'salsa',
#  610: 'easily',
#  611: 'STEP',
#  612: 'Cibo',
#  613: 'anticipated',
#  614: 'Before',
#  615: 'fat',
#  616: 'lacked',
#  617: 'Overall',
#  618: 'gratitude',
#  619: 'moist',
#  620: 'concern',
#  621: 'Avoid',
#  622: 'seasonal',
#  623: 'make',
#  624: 'all',
#  625: 'ever',
#  626: 'bye',
#  627: 'at',
#  628: 'every',
#  629: 'feeling',
#  630: 'rib',
#  631: 'Panna',
#  632: 'patron',
#  633: 'mom',
#  634: 'frozen',
#  635: 'serves',
#  636: 'packed',
#  637: 'Took',
#  638: 'Mango',
#  639: '/hand',
#  640: 'also',
#  641: 'salt',
#  642: 'Thoroughly',
#  643: 'pan',
#  644: 'Disappointing',
#  645: 'Flower',
#  646: 'proclaimed',
#  647: 'website',
#  648: 'seated',
#  649: 'world',
#  650: 'Delicious',
#  651: 'drunk',
#  652: 'rge',
#  653: 'gratuity',
#  654: 'inexpensive',
#  655: 'REAL',
#  656: 'gotten',
#  657: 'Costco',
#  658: 'They',
#  659: 'High-quality',
#  660: 'same',
#  661: 'beautiful',
#  662: 'THIS',
#  663: 'miss',
#  664: 'monster',
#  665: 'grandmother',
#  666: 'thick',
#  667: 'cranberry',
#  668: 'menu/',
#  669: 'Dos',
#  670: 'anything',
#  671: 'Lastly',
#  672: 'Salad',
#  673: 'lovely',
#  674: 'menu',
#  675: 'might',
#  676: 'mmmm',
#  677: 'wound',
#  678: 'satisfied',
#  679: 'melt',
#  680: 'pretty',
#  681: 'Hiro',
#  682: 'attack',
#  683: 'scene',
#  684: 'dressed',
#  685: 'disgust',
#  686: 'Main',
#  687: 'godfathers',
#  688: 'HANDS',
#  689: '%',
#  690: 'part',
#  691: 'meal',
#  692: 'cocktails',
#  693: 'melted',
#  694: 'breakfast',
#  695: 'potatoes',
#  696: 'made',
#  697: 'bits',
#  698: 'duo',
#  699: 'HOUR',
#  700: 'completely',
#  701: 'short',
#  702: 'consider',
#  703: 'two',
#  704: 'parties',
#  705: 'best',
#  706: 'loves',
#  707: 'Toast',
#  708: 'absolutley',
#  709: 'some',
#  710: 'cashew',
#  711: 'solid',
#  712: 'cake',
#  713: 'use',
#  714: 'email',
#  715: '3',
#  716: 'known',
#  717: 'dirty-',
#  718: 'So',
#  719: 'roast',
#  720: 'again',
#  721: 'Excalibur',
#  722: 'certainly',
#  723: 'crawfish',
#  724: 'bacon',
#  725: 'yellowtail',
#  726: 'healthy',
#  727: 'provided',
#  728: 'perfect',
#  729: 'diverse',
#  730: 'bagels',
#  731: 'words',
#  732: 'EXPERIENCE',
#  733: 'here',
#  734: 'brought',
#  735: 'guests',
#  736: 'BARE',
#  737: 'taco',
#  738: 'longer',
#  739: 'atmosphere.1',
#  740: 'Bisque',
#  741: 'Maine',
#  742: 'regularly',
#  743: 'truly',
#  744: 'Pineapple',
#  745: 'claimed',
#  746: 'waiting',
#  747: 'dog',
#  748: 'dishes',
#  749: 'person',
#  750: 'week',
#  751: 'bland',
#  752: 'mean',
#  753: 'Hunan',
#  754: 'Overpriced',
#  755: 'disgusting',
#  756: 'publicly',
#  757: 'Only',
#  758: 'Tried',
#  759: 'readers',
#  760: 'everyone',
#  761: 'middle',
#  762: 'absolute',
#  763: 'English',
#  764: 'thanks',
#  765: 'none',
#  766: 'Salads',
#  767: 'eyes',
#  768: 'so',
#  769: 'presentation',
#  770: 'touch',
#  771: 'Mediterranean',
#  772: 'ribeye',
#  773: 'past',
#  774: 'Bachi',
#  775: 'nude',
#  776: 'TOTAL',
#  777: 'Are',
#  778: 'circumstances',
#  779: 'temp.I',
#  780: 'delight',
#  781: 'Burrittos',
#  782: 'puree',
#  783: 'These',
#  784: 'perfection',
#  785: 'Chicken',
#  786: 'below',
#  787: 'realized',
#  788: 'huevos',
#  789: 'pop',
#  790: 'owner',
#  791: 'up',
#  792: 'unbelievable',
#  793: 'seems',
#  794: 'courteous',
#  795: 'received',
#  796: 'Place',
#  797: 'Special',
#  798: 'company',
#  799: 'saying',
#  800: 'NEVER',
#  801: 'outside',
#  802: 'waited',
#  803: 'mains',
#  804: 'mouths',
#  805: 'Come',
#  806: 'lacking',
#  807: 'juries',
#  808: 'number',
#  809: 'accountant',
#  810: 'literally',
#  811: 'hated',
#  812: 'decide',
#  813: 'capers',
#  814: 'bloddy',
#  815: 'fish',
#  816: 'North',
#  817: 'pulled',
#  818: 'tip',
#  819: 'behind',
#  820: 'doubt',
#  821: 'rowdy',
#  822: 'almost',
#  823: 'slaw',
#  824: 'much',
#  825: 'curry',
#  826: 'pho',
#  827: 'crepe',
#  828: 'low',
#  829: 'Ha',
#  830: 'instead',
#  831: 'dime',
#  832: 'desserts',
#  833: 'colder',
#  834: 'fruit',
#  835: 'barely',
#  836: 'original',
#  837: 'fucking',
#  838: 'peanuts',
#  839: 'Those',
#  840: 'Sprouts',
#  841: 'acknowledged',
#  842: 'ways',
#  843: 'server',
#  844: 'preparing',
#  845: 'outta',
#  846: 'could',
#  847: 'handling',
#  848: 'fo',
#  849: 'belly',
#  850: 'Egg',
#  851: 'beyond',
#  852: 'delivery',
#  853: 'salmon',
#  854: 'Long',
#  855: 'succulent',
#  856: 'clue',
#  857: 'Boy',
#  858: '30s',
#  859: 'Talk',
#  860: 'fuzzy',
#  861: "'ll",
#  862: 'customize',
#  863: 'complete',
#  864: 'nasty',
#  865: 'stay',
#  866: 'used',
#  867: 'had',
#  868: 'fried',
#  869: 'Crema',
#  870: 'rarely',
#  871: 'AYCE',
#  872: 'probably',
#  873: 'Could',
#  874: 'garden',
#  875: 'rice',
#  876: 'lil',
#  877: 'rave',
#  878: 'area/',
#  879: 'oh',
#  880: 'super',
#  881: 'Waiter',
#  882: 'thin',
#  883: 'means',
#  884: 'shocked',
#  885: 'From',
#  886: 'ordering',
#  887: 'The',
#  888: 'ourselves',
#  889: 'mess',
#  890: 'they',
#  891: 'hospitality',
#  892: 'mussels',
#  893: '2007',
#  894: 'recommending',
#  895: 'take',
#  896: 'sucker',
#  897: 'deal',
#  898: 'egg',
#  899: 'pucks',
#  900: 'section',
#  901: 'Noca',
#  902: 'manager',
#  903: 'mac',
#  904: 'Plus',
#  905: 'duck',
#  906: 'bars',
#  907: 'sub-par',
#  908: 'pub',
#  909: 'talk',
#  910: "ya'all",
#  911: 'elsewhere',
#  912: 'working/eating',
#  913: 'steaks',
#  914: 'suffers',
#  915: 'being',
#  916: 'itself',
#  917: 'grossed',
#  918: 'foot',
#  919: 'Crostini',
#  920: 'ambience',
#  921: 'Sushi',
#  922: 'grill',
#  923: 'pastas',
#  924: 'operation',
#  925: 'wings',
#  926: 'asked',
#  927: 'And',
#  928: 'summer',
#  929: 'consistent',
#  930: 'mood',
#  931: 'despicable',
#  932: 'crisp',
#  933: 'hamburger',
#  934: 'wontons',
#  935: '$',
#  936: 'downright',
#  937: 'Hot',
#  938: 'tacos',
#  939: 'sals',
#  940: 'Highly',
#  941: 'kid',
#  942: 'impressive',
#  943: 'allergy',
#  944: 'trips',
#  945: 'extremely',
#  946: 'amount',
#  947: '.THE',
#  948: 'Soggy',
#  949: 'petrified',
#  950: 'Eve',
#  951: 'Mexican',
#  952: 'favor',
#  953: '12',
#  954: 'Nan',
#  955: 'serving',
#  956: 'tasted',
#  957: 'vegetarian',
#  958: 'towards',
#  959: 'informative',
#  960: 'tasteless',
#  961: 'Mom',
#  962: 'sashimi',
#  963: 'surprised',
#  964: 'final',
#  965: 'name',
#  966: 'Risotto',
#  967: 'live',
#  968: 'Heimer',
#  969: 'cannoli',
#  970: 'Last',
#  971: 'green',
#  972: 'awful',
#  973: 'mind',
#  974: 'folks',
#  975: 'binge',
#  976: 'hello',
#  977: 'Have',
#  978: 'Host',
#  979: 'restaraunt',
#  980: 'weekend',
#  981: 'flat',
#  982: 'human',
#  983: 'WAAAAAAyyyyyyyyyy',
#  984: 'be',
#  985: 'better',
#  986: 'recommend',
#  987: 'kiddos',
#  988: '.way',
#  989: 'surprise',
#  990: 'highly',
#  991: '2',
#  992: 'customer',
#  993: 'hoping',
#  994: 'visit',
#  995: 'piano',
#  996: 'seen',
#  997: 'stop',
#  998: 'sat',
#  999: 'mention',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index_dic[word]] += 1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
np.zeros((len(whole_words),1))
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])
